# %% [markdown]
# ## 1. Storing User Details

# %%
user_details = {"name": "Taylor", "age": 34, "city": "New York"}
print(user_details)
# Out:
# {'name': 'Taylor', 'age': 34, 'city': 'New York'}

# %% [markdown]
# ## 2. Counting Occurrences

# %%
sentence = "Python is great and Python is fun"
word_count = {}
for word in sentence.split():
    word = word.lower() # Normalizar las palabras a lower
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(word_count)

# %% [markdown]
# ## 3. Quick Access to Information

# %%
print(user_details["age"])

# Tips for Using Dictionaries Effectively

age = user_details.get("age", 'Not found')
print(age)

gender = user_details.get("gender", 'Not specified')
print(gender)

# Avoid Duplicate Keys: new values to an existing key -->  update de value

user_details["age"] = 35.   # Update age value
print (user_details)

# Iterate Over Dictionaries: 

for (key, value) in user_details.items():
    print(f"{key}:{value}")
# Out:
# 35.0
# 35.0
# Not specified
# {'name': 'Taylor', 'age': 35.0, 'city': 'New York'}
# name:Taylor
# age:35.0
# city:New York

# %% [markdown]
# # Real example where Dictionaries can be used

# %% [markdown]
# ### 1. Storing User Information

# %%
user_profiles = {
    "alice": {"password":"alice123", "email":"alice@example.com"},
    "bob": {"password":"bob456", "email":"bob@example.com"}
}

# %% [markdown]
# ### 2. Contact Management

# %%
contacts = {
    "John Smith": {"phone": "123-456-7890", "email": "john@example.com"},
    "Jane Doe": {"phone": "987-654-3210", "email": "jane@example.com"}
}

# %% [markdown]
# ### 3. Inventory Management

# %%
inventory = {
"apples": 50,
"oranges": 30,
"bananas": 20
}

# %% [markdown]
# ## 4. Counting Occurrences

# %%
text = "apple banana apple orange banana apple"
word_count = {}

for word in text.split():
    word_count[word] = word_count.get(word, 0)+1

print(word_count)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %% [markdown]
# ## 5. Caching Data

# %%
cache = {}

def expensive_computation(x):
    if x in cache:
        print("Usando cache")
        return cache[x]
    
    print("Calculando...")
    result = x**2
    cache[x] = result
    return result


print(expensive_computation(4))
print(expensive_computation(4))
# Out:
# Calculando...
# 16
# Usando cache
# 16
