# %% [markdown]
# # Getting Started with characters & strings

# %%
import pandas as pd
import numpy as np

# %%
#__string = "He said, \"Datacamp\"" 
__string = "He said, 'Datacamp'" # Las 2 opciones son validas para no tener errores y poder poner entr ""
print(__string)
# Out:
# He said, 'Datacamp'

# %%
"beekepers".split("e")
# Out:
# ['b', '', 'k', 'p', 'rs']

# %% [markdown]
# # Getting started with DataFrames

# %%
# Create DataFrame from Dictionary
pd.DataFrame({
    'a': [1, 2, 3],
    'b': np.array([4, 4, 6]),
    'c': ['x', 'x', 'y']
})
# Out:
#    a  b  c
# 0  1  4  x
# 1  2  4  x
# 2  3  6  y

# %%
# Create a DataFrame from a list of dictionaries

df = pd.DataFrame([
    {'a': 1, 'b': 4, 'c': 'x'},
    {'a': 1, 'b': 4, 'c': 'x'},
    {'a': 4, 'b': 6, 'c': 'y'},
])
df
# Out:
#    a  b  c
# 0  1  4  x
# 1  1  4  x
# 2  4  6  y

# %% [markdown]
# ### Selecting DataFrame Elements

# %%
df.iloc[2]
# Out:
# a    4
# b    6
# c    y
# Name: 2, dtype: object

# %%
df['b']
# Out:
# 0    4
# 1    4
# 2    6
# Name: b, dtype: int64

# %%
df.loc[2,'b']
# Out:
# np.int64(6)

# %%
df[['a', 'c']]
# Out:
#    a  c
# 0  1  x
# 1  1  x
# 2  4  y

# %% [markdown]
# ### Manipulating DataFrames

# %%
#Concatenate Vertically
pd.concat([df, df])
# Out:
#    a  b  c
# 0  1  4  x
# 1  1  4  x
# 2  4  6  y
# 0  1  4  x
# 1  1  4  x
# 2  4  6  y

# %%
# Concatenate horizontally
pd.concat([df, df], axis = 'columns')
# Out:
#    a  b  c  a  b  c
# 0  1  4  x  1  4  x
# 1  1  4  x  1  4  x
# 2  4  6  y  4  6  y

# %%
# add a new column
df.assign(temp_f=9 / 5 + 32)
# Out:
#    a  b  c  temp_f
# 0  1  4  x    33.8
# 1  1  4  x    33.8
# 2  4  6  y    33.8
