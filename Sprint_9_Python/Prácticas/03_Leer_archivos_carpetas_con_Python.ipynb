# %% [markdown]
# # Ejemplo 3

# %%
import os
ruta = os.listdir('/Users/rogerdefez/Documents/VSCWorkspace/Data-Science-Project/Datos para ejercicios')
ruta
# Out:
# ['Pedidos.xlsx',
#  'Productos.xlsx',
#  'February 2019.csv',
#  'Motocicletas gasolina.csv',
#  'Neptuno-2003-script.sql',
#  'Datos Accidentes localidad.csv',
#  'January 2019.csv',
#  'March 2019.csv',
#  'Clientes.xlsx',
#  'Categorías.xlsx',
#  'Detalles Pedidos.xlsx',
#  'VentasGroucery_Meses.xlsx',
#  'Comerciales.xlsx',
#  'Datos Pedidos.xlsx']

# %%
listaexcels = []
for file in ruta:
    if file.endswith(".xlsx") or file.endswith(".xls"):
        listaexcels.append(file)

listaexcels
# Out:
# ['Pedidos.xlsx',
#  'Productos.xlsx',
#  'Clientes.xlsx',
#  'Categorías.xlsx',
#  'Detalles Pedidos.xlsx',
#  'VentasGroucery_Meses.xlsx',
#  'Comerciales.xlsx',
#  'Datos Pedidos.xlsx']

# %%
# compreensive list or Pythonic list

listaexcels = [file for file in ruta if file.endswith(".xlsx") or file.endswith(".xls")]

listaexcels
# Out:
# ['Pedidos.xlsx',
#  'Productos.xlsx',
#  'Clientes.xlsx',
#  'Categorías.xlsx',
#  'Detalles Pedidos.xlsx',
#  'VentasGroucery_Meses.xlsx',
#  'Comerciales.xlsx',
#  'Datos Pedidos.xlsx']

# %%
import pandas as pd
for file in listaexcels:
    suf = suf =+ 1
    df = pd.DataFrame('/Users/rogerdefez/Documents/VSCWorkspace/Data-Science-Project/Datos para ejercicios'+file) 
    df+"suf" == df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/6f/lhr87vh51bq38sm9v46389m00000gn/T/ipykernel_202/442140464.py in ?()
#       1 import pandas as pd
#       2 for file in listaexcels:
#       3     suf = suf =+ 1
# ----> 4     df = pd.DataFrame('/Users/rogerdefez/Documents/VSCWorkspace/Data-Science-Project/Datos para ejercicios'+file)
#       5     df+"suf" == df
#
# ~/Documents/Cursos i Llibres/BootCamp IT Academy/03_Especialitzacio/.venv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     865                 )
#     866         # For data is scalar
#     867         else:
#     868             if index is None or columns is None:
# --> 869                 raise ValueError("DataFrame constructor not properly called!")
#     870
#     871             index = ensure_index(index)
# ...
