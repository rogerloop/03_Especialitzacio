# %% [markdown]
#  # 1. CREAR DATAFRAMES

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# A partir de una lista de listas
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ["A","B","C"])
# añadir más filas seria añadiendo otra sublista
# para añadir columnas alargo la sublista
# para añadir las filas se haría con la parte de columns
df

# A partir de diccionario (mejor que lista de listas)
df = pd.DataFrame({"A" : [1,4,7,10], "B" : [2,5,8,11] , "C" : ["Q","W","E","R"]})
df
# Out:
#     A   B  C
# 0   1   2  Q
# 1   4   5  W
# 2   7   8  E
# 3  10  11  R

# %% [markdown]
# # 2. IMPORTACION DE ARCHVOS

# %%
df = pd.read_csv(r"C:\code\CURSOS\BOOTCAMP_DATA_IT ACADEMY_2025_2026\examen\DATOS\iris_dataset.csv")

df

#OJO hay que poner el nombre y la extension al final de la ruta

df2 = pd.read_excel(r"C:\code\CURSOS\BOOTCAMP_DATA_IT ACADEMY_2025_2026\examen\DATOS\Cursos (27).xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
# ...

# %% [markdown]
# ORDENAR POR PAIS Y SI HAY EMPATE POR CIUDAD (APTES DEL SPRINT 10)

# %%
# df_people_sorted = df_people.sort_values(["País d'origen", "Ciutat"])
